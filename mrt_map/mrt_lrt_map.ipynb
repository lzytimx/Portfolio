# %%
import pandas as pd
import numpy as np
import requests
import geopandas as gpd
import os
import datetime
import time
import folium
from shapely.geometry import LineString

# %%
pd.set_option('display.max_columns', None)
pd.set_option("display.max_rows", None)

# %%
mrt_file_loc = "../datasets/sg_mrt_lrt/mrt_stations.shp"
mrt_gdf = gpd.read_file(mrt_file_loc)

mrt_gdf["OPENING"] = pd.to_datetime(mrt_gdf["OPENING"])
mrt_gdf = mrt_gdf.rename(columns={"STATION_NA": "STATION_NAME"})
mrt_gdf["lat_lng"] = gpd.points_from_xy(mrt_gdf["LATITUDE"], mrt_gdf["LONGITUDE"])

mrt_gdf.head()
# mrt_gdf.crs
# Out:
#   CODE   STATION_NAME              LINE COLOR    OPENING TYPE  \
# 0  NS1    Jurong East  North-South Line   Red 1990-03-10  MRT
# 1  NS2    Bukit Batok  North-South Line   Red 1990-03-10  MRT
# 2  NS3   Bukit Gombak  North-South Line   Red 1990-03-10  MRT
# 3  NS4  Choa Chu Kang  North-South Line   Red 1990-03-10  MRT
# 4  NS5        Yew Tee  North-South Line   Red 1996-02-10  MRT
#
#                               SEARCHVAL BLK_NO                  ROAD_NAME  \
# 0  JURONG EAST MRT STATION (EW24 / NS1)     10      JURONG EAST STREET 12
# 1         BUKIT BATOK MRT STATION (NS2)     10        BUKIT BATOK CENTRAL
# 2        BUKIT GOMBAK MRT STATION (NS3)    802  BUKIT BATOK WEST AVENUE 5
# 3       CHOA CHU KANG MRT STATION (NS4)     10     CHOA CHU KANG AVENUE 4
# 4             YEW TEE MRT STATION (NS5)     61        CHOA CHU KANG DRIVE
#
#                                BUILDING  \
# 0  JURONG EAST MRT STATION (EW24 / NS1)
# 1         BUKIT BATOK MRT STATION (NS2)
# 2        BUKIT GOMBAK MRT STATION (NS3)
# 3       CHOA CHU KANG MRT STATION (NS4)
# 4             YEW TEE MRT STATION (NS5)
#
#                                              ADDRESS  POSTAL  \
# 0  10 JURONG EAST STREET 12 JURONG EAST MRT STATI...  609690
# 1  10 BUKIT BATOK CENTRAL BUKIT BATOK MRT STATION...  659958
# 2  802 BUKIT BATOK WEST AVENUE 5 BUKIT GOMBAK MRT...  659083
# 3  10 CHOA CHU KANG AVENUE 4 CHOA CHU KANG MRT ST...  689810
# 4  61 CHOA CHU KANG DRIVE YEW TEE MRT STATION (NS...  689715
#
#                   X                 Y          LATITUDE         LONGITUDE  \
# 0  17869.0570516568  35038.9688695427  1.33315281585758  103.742286332403
# 1  18679.3223191258  36794.9260214306  1.34903331201636  103.749566478309
# 2  18926.9127006577  37854.0358848721  1.35861159094192  103.751790910733
# 3  18101.2472041463  40812.1216052417  1.38536316540225  103.744370779756
# 4  18438.9831173802  42158.0181021616  1.39753506936297  103.747405150236
#
#                       geometry                lat_lng
# 0  POINT (17869.057 35038.969)  POINT (1.333 103.742)
# 1  POINT (18679.322 36794.926)  POINT (1.349 103.750)
# 2  POINT (18926.913 37854.036)  POINT (1.359 103.752)
# 3  POINT (18101.247 40812.122)  POINT (1.385 103.744)
# 4  POINT (18438.983 42158.018)  POINT (1.398 103.747)

# %%
def check_codes(row):
    for_check = row["CODE"]
    if len(for_check) == 3 and for_check[-1].isdigit():
        result = for_check.replace(for_check[-1], f"0{for_check[-1]}")
        return result
    else:
        result = for_check
        return result


mrt_gdf["CODE"] = mrt_gdf.apply(check_codes, axis=1)

# %%
gdf_for_concat = []
new_codes_STC = ['SE00', 'SE06', 'SW00', 'SW09']
new_codes_PTC = ["PW00", "PW08", "PE00", "PE08"]

for i in new_codes_PTC:
    temp = mrt_gdf.query("CODE == 'PTC'")
    temp.loc[:, 'CODE'] = i
    gdf_for_concat.append(temp)

for i in new_codes_STC:
    temp = mrt_gdf.query("CODE == 'STC'")
    temp.loc[:, "CODE"] = i
    gdf_for_concat.append(temp)

temp = mrt_gdf.query("CODE == 'BP06'")
temp.loc[:, "CODE"] = 'BP14'
gdf_for_concat.append(temp)

temp = mrt_gdf.query("CODE == 'EW04'")
temp.loc[:, "CODE"] = "CG00"
gdf_for_concat.append(temp)

temp = mrt_gdf.query("CODE == 'CC04'")
temp.loc[:, "CODE"] = "CE00"
gdf_for_concat.append(temp)

concat_list = pd.concat(gdf_for_concat, axis=0)
# concat_list

# %%
mrt_gdf_lines = pd.concat([mrt_gdf, concat_list], axis=0).sort_values("CODE").reset_index(drop=True)
mrt_gdf_lines.head()
# Out:
#    CODE   STATION_NAME               LINE COLOR    OPENING TYPE  \
# 0  BP01  Choa Chu Kang  Bukit Panjang LRT  Grey 1999-11-06  LRT
# 1  BP02     South View  Bukit Panjang LRT  Grey 1999-11-06  LRT
# 2  BP03      Keat Hong  Bukit Panjang LRT  Grey 1999-11-06  LRT
# 3  BP04      Teck Whye  Bukit Panjang LRT  Grey 1999-11-06  LRT
# 4  BP05        Phoenix  Bukit Panjang LRT  Grey 1999-11-06  LRT
#
#                          SEARCHVAL BLK_NO               ROAD_NAME  \
# 0  CHOA CHU KANG LRT STATION (BP1)     15  CHOA CHU KANG AVENUE 4
# 1     SOUTH VIEW LRT STATION (BP2)     50       CHOA CHU KANG WAY
# 2      KEAT HONG LRT STATION (BP3)     30       CHOA CHU KANG WAY
# 3      TECK WHYE LRT STATION (BP4)     10       CHOA CHU KANG WAY
# 4        PHOENIX LRT STATION (BP5)     40      CHOA CHU KANG ROAD
#
#                           BUILDING  \
# 0  CHOA CHU KANG LRT STATION (BP1)
# 1     SOUTH VIEW LRT STATION (BP2)
# 2      KEAT HONG LRT STATION (BP3)
# 3      TECK WHYE LRT STATION (BP4)
# 4        PHOENIX LRT STATION (BP5)
#
#                                              ADDRESS  POSTAL  \
# 0  15 CHOA CHU KANG AVENUE 4 CHOA CHU KANG LRT ST...  689813
# 1  50 CHOA CHU KANG WAY SOUTH VIEW LRT STATION (B...  688265
# 2  30 CHOA CHU KANG WAY KEAT HONG LRT STATION (BP...  688266
# 3  10 CHOA CHU KANG WAY TECK WHYE LRT STATION (BP...  688267
# 4  40 CHOA CHU KANG ROAD PHOENIX LRT STATION (BP5...  689483
#
#                   X                 Y          LATITUDE         LONGITUDE  \
# 0  18119.8205469949  40744.9184182286  1.38475541089131   103.74453769781
# 1    18203.72427563  40252.0686228592  1.38029828742399  103.745291799824
# 2  18622.5893422375  40064.6246900782   1.3786032506373  103.749055668925
# 3  19140.8000152688  39852.4607739244  1.37668467920808  103.753712232337
# 4  19617.4881601976  40065.9404090624  1.37861545104083  103.757995558346
#
#                       geometry                lat_lng
# 0  POINT (18119.821 40744.918)  POINT (1.385 103.745)
# 1  POINT (18203.724 40252.069)  POINT (1.380 103.745)
# 2  POINT (18622.589 40064.625)  POINT (1.379 103.749)
# 3  POINT (19140.800 39852.461)  POINT (1.377 103.754)
# 4  POINT (19617.488 40065.940)  POINT (1.379 103.758)

# %%
interchanges = mrt_gdf["STATION_NAME"].value_counts()
interchanges = interchanges[interchanges > 1].index

mrt_gdf['interchange'] = mrt_gdf["STATION_NAME"].apply(lambda x: True if x in interchanges else False)

# %%
# Create the 'grouper' column
mrt_gdf_lines["grouper"] = mrt_gdf_lines["CODE"].str.slice(0, 2)

# Group by 'grouper' and create LineString geometries
def create_linestring(group):
    # Check if there are at least two points to create a LineString
    if len(group) > 1:
        return LineString(group.to_list())
    else:
        # Return the original geometry if not enough points for a LineString
        return group.iloc[0]

# Apply the function to create LineString geometries
test_df = mrt_gdf_lines.groupby(["grouper", "COLOR"])["lat_lng"].apply(create_linestring)

# Convert the resulting Series to a GeoDataFrame
geo_df2 = gpd.GeoDataFrame(test_df, geometry="lat_lng").reset_index()

lines_gdf = geo_df2[geo_df2.geometry.type == "LineString"]
lines_gdf
# Out:
#    grouper   COLOR                                            lat_lng
# 0       BP    Grey  LINESTRING (1.385 103.745, 1.380 103.745, 1.37...
# 1       CC  Orange  LINESTRING (1.299 103.846, 1.297 103.851, 1.29...
# 2       CE  Orange  LINESTRING (1.294 103.860, 1.282 103.859, 1.27...
# 3       CG   Green  LINESTRING (1.327 103.946, 1.335 103.962, 1.35...
# 4       DT    Blue  LINESTRING (1.379 103.762, 1.370 103.764, 1.36...
# 5       EW   Green  LINESTRING (1.373 103.949, 1.353 103.945, 1.34...
# 6       NE  Purple  LINESTRING (1.265 103.822, 1.280 103.839, 1.28...
# 7       NS     Red  LINESTRING (1.333 103.742, 1.349 103.750, 1.35...
# 8       PE    Grey  LINESTRING (1.405 103.902, 1.399 103.906, 1.39...
# 10      PW    Grey  LINESTRING (1.405 103.902, 1.410 103.905, 1.41...
# 11      SE    Grey  LINESTRING (1.392 103.895, 1.394 103.900, 1.39...
# 13      SW    Grey  LINESTRING (1.392 103.895, 1.396 103.894, 1.39...
# 14      TE   Brown  LINESTRING (1.448 103.786, 1.436 103.788, 1.42...

# %%
color_dict = {
    "Red": "#c03731",
    "Green": "#1f844d",
    "Purple": "#953aa6",
    "Orange": "#fba01d",
    "Blue": "#134f9a",
    "Brown": "#9d6633",
    "Grey": "#8c958c",
}

m_1 = folium.Map(location=[1.3521, 103.8198], zoom_start=12, tiles="cartodbpositron") # tiles="cartodbpositron"

for index, row in geo_df2.iterrows():
    color = color_dict[row['COLOR']]
    locations = [(coord[0], coord[1]) for coord in row["lat_lng"].coords]
    folium.PolyLine(
        locations=locations,
        color=color,
        weight=2,
    ).add_to(m_1)

for index, row in mrt_gdf.iterrows():
    color = color_dict[row["COLOR"]]
    tooltip = f"""
    <div style="color: white; background-color: {color}; padding: 5px; border-radius: 5px;">
        <b>{row['CODE']}: {row['STATION_NAME']} {row['TYPE']} Station</b>
    </div>
    """
    if row['interchange']:
        radius=6
        folium.CircleMarker(
            location=[row["LATITUDE"], row["LONGITUDE"]],
            radius=radius,
            weight=2,
            color="black",  # colour of corder
            fill_color=color,
            fill_opacity=1,
            tooltip=tooltip,
        ).add_to(m_1)
    else:
        radius=3
        folium.CircleMarker(
            location=[row["LATITUDE"], row["LONGITUDE"]],
            radius=radius,
            weight=1,
            color=color,
            fill_color=color,
            fill_opacity=1,
            tooltip=tooltip,
        ).add_to(m_1)


m_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20a42a670a206eb40830ff8425c91850 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20a42a670a206eb40830ff8425c91850&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20a42a670a206eb40830ff8425c91850 = L.map(
#                 &quot;map_20a42a670a206eb40830ff8425c91850&quot;,
#                 {
#                     center: [1.3521, 103.8198],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38ce806a08fc06edf10a138f28b13d2c = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_38ce806a08fc06edf10a138f28b13d2c.addTo(map_20a42a670a206eb40830ff8425c91850);
#
#
#             var poly_line_761facf01f92e8a34373324608c96198 = L.polyline(
#                 [[1.38475541089131, 103.74453769781], [1.38029828742399, 103.745291799824], [1.3786032506373, 103.749055668925], [1.37668467920808, 103.753712232337], [1.37861545104083, 103.757995558346], [1.37792694616982, 103.763102931112], [1.37777204259082, 103.766645782497], [1.37613574334988, 103.771261175571], [1.38002223010088, 103.772647370452], [1.38457317668026, 103.770887223018], [1.38778508663361, 103.769599685249], [1.38673926997961, 103.76453408646], [1.38272547134453, 103.76234425472], [1.37792694616982, 103.763102931112]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#8c958c&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#8c958c&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_20a42a670a206eb40830ff8425c91850);
#
#
#             var poly_line_add5a74e1688463859915a9c700e2d02 = L.polyline(
#                 [[1.29891164362677, 103.84629250696], [1.29686168649656, 103.850667371637], [1.2936577245386, 103.855081226245], [1.29399798636232, 103.860350000188], [1.29976684675139, 103.86363696572], [1.3028124684707, 103.875337711089], [1.30620190525331, 103.882528081052], [1.30854798388121, 103.889064718377], [1.3172473854035, 103.892260753884], [1.32607760171665, 103.890391305725], [1.33514150139202, 103.888389300191], [1.34250117805245, 103.880177899184], [1.35063361526525, 103.872771660431], [1.35161217074555, 103.864151938651], [1.35131580146658, 103.84914026532], [1.348707263451, 103.839423132332], [1.33767450815619, 103.839529820338], [1.32211373558877, 103.814984510627], [1.31743915158967, 103.807379214161], [1.31224029631595, 103.796399122407], [1.30663450405, 103.790709404436], [1.29975987493555, 103.78745750525], [1.29353349887123, 103.784572738173], [1.28257135772488, 103.781752725064], [1.27621352233766, 103.791350313288], [1.27225417749656, 103.802631578766], [1.27070647717762, 103.809761611219], [1.26538938374901, 103.821530157095]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fba01d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#fba01d&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_20a42a670a206eb40830ff8425c91850);
#
#
#             var poly_line_79ee56cb4c5e8e219c7ec203f074cb62 = L.polyline(
#                 [[1.29399798636232, 103.860350000188], [1.28187378879209, 103.859079764874], [1.27625146423743, 103.855447156279]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#fba01d&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#fba01d&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2}
#             ).addTo(map_20a42a670a206eb40830ff8425c91850);
#
#
#             var poly_line_329e3ac2db3e628d7d961f39072ac1ff = L.polyline(
#                 [[1.32718729074675, 103.946348600798], [1.33454977824817, 103.961548211018], [1.35747897447692, 103.98788356959]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#1f844d&quot;, &quot;dashArray&quot;: nu

# %% [markdown]
# <img src='https://www.lta.gov.sg/content/dam/ltagov/getting_around/public_transport/rail_network/pdf/tel3_sm-en.png' width='100%'>
